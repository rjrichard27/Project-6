# %% [markdown]
# <a href="https://colab.research.google.com/github/rjrichards27/Project-6/blob/main/Project6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest Data

# %%
import spacy
spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
from pathlib import Path
import spacy

# %% [markdown]
# This code downloads *The Bell Jar* by Slyvia Plat.

# %%
# !wget https://raw.githubusercontent.com/rjrichard27/Project-6/main/TheBellJar.txt
# Out:
# --2021-09-23 12:52:21--  https://raw.githubusercontent.com/rjrichard27/Project-6/main/TheBellJar.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375977 (367K) [text/plain]
# Saving to: ‘TheBellJar.txt’
#
# TheBellJar.txt      100%[===================>] 367.17K  --.-KB/s    in 0.03s
#
# 2021-09-23 12:52:22 (10.2 MB/s) - ‘TheBellJar.txt’ saved [375977/375977]

# %%
tbj_text = Path("TheBellJar.txt").read_text()

# %%
tbj_text
# Out:
# 'Chapter One\n\nIt was a queer, sultry summer, the summer they electrocuted the\nRosenbergs, and I didn\'t know what I was doing in New York.  I\'m stupid\nabout executions.  The idea of being electrocuted makes me sick, and\nthat\'s all there was to read about in the papers--goggle-eyed headlines\nstaring up at me on every street corner and at the fusty,\npeanut-smelling mouth of every subway.  It had nothing to do with me,\nbut I couldn\'t help wondering what it would be like, being burned alive\nall along your nerves.\n\nI thought it must be the worst thing in the world.\n\nNew York was bad enough.  By nine in the morning the fake, country-wet\nfreshness that somehow seeped in overnight evaporated like the tail end\nof a sweet dream.  Mirage-grey at the bottom of their granite canyons,\nthe hot streets wavered in the sun, the car tops sizzled and glittered,\nand the dry, tindery dust blew into my eyes and down my throat.\n\nI kept hearing about the Rosenbergs over the radio and at
# ...

# %% [markdown]
# Word Visualizations

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
#remove stop words
from textblob import TextBlob
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
tbj_blob = TextBlob(Path('TheBellJar.txt').read_text())

# %%
tbj_count = tbj_blob.word_counts.items()

# %%
from pandas import DataFrame
df = DataFrame(no_stop_words)
df.head()
df.to_csv("tbj_word_count.csv")

# %%
def remove_stop(words):
  no_stop = []
  for word in words:
    if word[0] not in stop_words:
      no_stop.append(word[0])
  return no_stop

# %%
no_stop_words = remove_stop(tbj_count)

# %%
len(no_stop_words)
# Out:
# 7086

# %% [markdown]
# World Cloud

# %%
from wordcloud import WordCloud

# %%
word_cloud_text = str1 = ' '.join(no_stop_words)
wordCloud = WordCloud().generate(word_cloud_text)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# #Cloud-based NoCode-LowCode Tool

# %%
from pandas import DataFrame
df= DataFrame(no_stop_words, columns = ["The Bell Jar Words"])

# %%
df.to_csv("The Bell Jar Words.txt", index=False)
